# %% [markdown]
# <img src="https://storage.googleapis.com/yggdrasil-ai-hermod-public/square%20logo.png" width="100" align="right">
#
# # Welcome to Talking with AI
#
# This notebook has been prepared for being executed in Google Colab. However, Colab's free resources are no more than _just enough_ to run the Open Source path. Using Falcon 7B Instruct is advised.
#
# It's interesting to keep an eye on resource usage, in the top right corner.
#
# Sometimes, some cells may take time to run, and the runtime environment may crash because of a memory error. An Addenda section with cells to recover state has been added at the notebook's end.
#
# ------
#
# If running this notebook locally, the resource usage will depend on your available local resources, and you may get more speed and/or run other OS models.

# %% [markdown]
# # Set up the environment

# %% [markdown]
# ## LLM installation and setup

# %%
import json
import re

# %% [markdown]
# ### OpenAI path

# %%
# !pip install openai tiktoken

# %% [markdown]
# To utilize OpenAI's GPT models, you need to first acquire an API key. This key can be generated after signing up for a free trial on [OpenAI's website](https://beta.openai.com/signup/). Post registration, visit the 'View API Keys' section in your 'Personal' menu, to get your OpenAI API Key. You'll need to insert this key into the next cell, replacing 'Your-API-Key' (in the instruction `openai.api_key = "Your-Api-Key"`) with your actual key.
#
# If you're interested in an open-source alternative, you could opt for HuggingFace's Transformers Path, leveraging the FalconInstruct7B model. This choice, may lead to lower performance and longer wait times in comparison to OpenAI's GPT models.

# %%
import openai
openai.api_key = "<your-api-key>"
PROVIDER = "openai"

# %%
openai.ChatCompletion.create(model="gpt-3.5-turbo", messages=[{"role": "user", "content": "Hello world"}])

# %% [markdown]
# ### Hugging Face's Transformers path
#
# If following this path, it is recommended to change the execution environment to one that utilizes Graphics Processing Units (GPUs). To do this, navigate to the "Runtime" menu, click on "Change runtime type", then select "GPU" from the dropdown menu under "Hardware accelerator". Remember to click "Save" to apply the changes. This will allow you to take advantage of Colab's free GPU resources and reduce the execution times.

# %%
# !nvidia-smi

# %%
# %pip install git+https://github.com/huggingface/transformers

# %%
# %pip install accelerate einops langchain

# %%
from transformers import AutoTokenizer

interesting_models = {
    #"mistral": {
    #    "7B": {
    #        "Instruct": "mistralai/Mistral-7B-Instruct-v0.1",
    #        "Basic": "mistralai/Mistral-7B-v0.1"
    #    }
    #},
    #"llama-2": {
    #    "7B": {
    #        "Chat": "meta-llama/Llama-2-7b-chat-hf",
    #        "Basic": "meta-llama/Llama-2-7b-hf"
    #    },
    #    "13B": {
    #        "Chat": "meta-llama/Llama-2-13b-chat-hf",
    #        "Basic": "meta-llama/Llama-2-13b-hf"
    #    },
    #    "70": {
    #        "Chat": "meta-llama/Llama-2-70b-chat-hf",
    #        "Basic": "meta-llama/Llama-2-70b-hf"
    #    }
    #},
    "falcon": {
        "7B": {
            "Instruct": "tiiuae/falcon-7b-instruct"
        },
        # "180B": {
        #    "Chat": "tiiuae/falcon-180B-chat",
        #    "Basic": "tiiuae/falcon-180B"
        #}
    }
}

PROVIDER = "falcon"
SIZE = "7B"
FINETUNING = "Instruct"

model = interesting_models[PROVIDER][SIZE][FINETUNING]
print(model)

tokenizer = AutoTokenizer.from_pretrained(model)

# %% [markdown]
# Let's now download our model's weights. Keep an eye over the "resources" window to check its resource usage.

# %%
import torch
import transformers

PIPELINE = transformers.pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    torch_dtype=torch.bfloat16,
    device_map="auto",
    max_length=1000,
    do_sample=True,
    top_k=10,
    num_return_sequences=1,
    eos_token_id=tokenizer.eos_token_id,
    pad_token_id=tokenizer.eos_token_id,
)

# %% [markdown]
# # Let's prepare our Agent entity
#
# An AIAgent represents a conversational AI, designed to manage a dialogue flow. This abstraction eases interactions with underlying AI models, with the goal of providing a more human-like interaction with AI, thus making it an effective dialogue partner.
#
# Agents can be equipped with the ability to perform a variety of "actions" - specific tasks initiated by prompts or responses - and can be utilized through different "integrations" - conversational interfaces. When equipped and utilized in this way, agents can handle diverse interactions and deliver dynamic responses across different contexts, positioning them as intelligent entities. The human-like presentation of this entity facilitates the construction of modular systems, adhering to robust patterns, thus establishing the Agent abstraction as an effective tool for system development.
#
# Agents used in this workshop will be very simple, and in the following section we will focus in creating the abstraction's class able to manage the dialogue flow. Each agent will be equipped with specific attributes: a name, personality, context (representing their knowledge), and goal (indicating their objective in each conversation). Additionally, they'll have an attribute determining which underlying AI model to use for generating responses.

# %% [markdown]
# ## Declare LLM serving function
#
# We will build a dict with different serving functions to abstract the choice between OpenAI GPT models and HuggingFace Falcon model. If you are following just one path, execute only the cells corresponding to that path. This abstraction ensures flexibility, enabling you to easily switch between the different models as per your requirements.

# %%
LLM_SERVING_FN = {}

# %% [markdown]
# ### OpenAI path

# %%
import tiktoken

openai_model = "gpt-3.5-turbo"

def count_tokens(text, model):
    """
    This function counts the number of tokens in a text.
    Parameters:
        text: The text to count the tokens of.
        model: The model to use for tokenization.
    Returns:
        The number of tokens in the text."""
    encoding = tiktoken.encoding_for_model(model)
    return len(encoding.encode(text))

def generate_answer(conversation_info):
    """
    This function will continue the conversation.
    Parameters:
        conversation_info: The information of the conversation
        message: The message to append
    """
    print("Generating answer")
    messages = [{"role": "system", "content": conversation_info["system_prompt"]}]
    for msg in conversation_info["messages"]:
        new_message = {"role": msg["role"] if msg["role"] \
                         in ("user", "assistant", "system") else "function",
                         "content": msg["content"]}
        if new_message["role"] == "function":
          new_message["name"] = "unknown"
        messages.append(new_message)

    # Limit the conversation history to a certain number of tokens
    max_context_length = 3500  # Adjust this value based on your desired context length
    current_context_length = sum([count_tokens(msg["content"], openai_model) for msg in messages])

    while current_context_length > max_context_length:
        removed_message = messages.pop(1)  # Remove the earliest non-system message
        current_context_length -= count_tokens(removed_message["content"], openai_model)

    full_prompt = {
        "model": openai_model,
        "messages": messages
    }
    response = openai.ChatCompletion.create(**full_prompt)
    return response["choices"][0]["message"]["content"]

def simple_prompt(prompt):
    full_prompt = {
        "model": openai_model,
        "messages": [{"role": "user", "content": prompt},]
    }
    response = openai.ChatCompletion.create(**full_prompt)
    return response["choices"][0]["message"]["content"]

LLM_SERVING_FN["plain"]["openai"] = simple_prompt

LLM_SERVING_FN["openai"] = generate_answer

# %% [markdown]
# ### Open Source Path

# %%
from langchain import HuggingFacePipeline

llm = HuggingFacePipeline(pipeline=PIPELINE)

def generate_answer(conversation_info):
    """
    This function will continue the conversation.
    Parameters:
        conversation_info: Dict object containing the information of the conversation
        message: The message to append
    """

    # Format messages to be compatible with the model
    prompt = conversation_info["system_prompt"] + "\n"
    for msg in conversation_info["messages"]:
        prompt += msg["role"].capitalize() + ": " + msg["content"] + "\n"

    # Generate response
    response = llm(prompt + "Assistant:")
    return response.split("User")[0]

LLM_SERVING_FN[PROVIDER] = generate_answer
LLM_SERVING_FN["plain"][PROVIDER] = llm

# %% [markdown]
# ## Declare Agent Class
#
# An AI Agent may be thought of as a 'virtual persona', with some personality, some goal, and the context it's aware of. Let's build that class.

# %%
SYSTEM_PROMPT = """You're an AI assistant called {name}.
This is your personality:
{personality}.

You are aware of the following context:
{context}.
When you don't know something, you say it. Your knowledge is focused in your context.

Your goal in this conversation is:
{goal}.
You must focus in your goal, if user tries to change conversation topic, you should dismiss it. You never write on behalf of user. You only write Assistant Messages. You only write one message at a time.
"""

# %%
class AIAgent:

    def __init__(self, name, personality, model_provider, context, goal):
        self.name = name
        self.personality = personality
        self.model_provider = model_provider
        self.context = context
        self.goal = goal
        self.conversation = []

    def _create_conversation(self):
        system_prompt = SYSTEM_PROMPT.format(
            context=self.context,
            personality=self.personality,
            name=self.name,
            goal=self.goal
        )
        conversation_info = {
            "system_prompt": system_prompt,
            "model_provider": self.model_provider,
            "messages": []
        }
        self.conversation=conversation_info

    def continue_conversation(self, message):
        # append user message to the conversation
        self.conversation["messages"].append({
            "role": "user",
            "content": message
        })
        # generate agent response
        agent_response = LLM_SERVING_FN[self.conversation["model_provider"]](
            self.conversation)
        # append agent response to the conversation
        self.conversation["messages"].append({
            "role": "assistant",
            "content": agent_response
        })
        return agent_response

    def create_conversation(self):
        # start a new conversation
        self._create_conversation()

        while True:
          # get user input
          user_message = input("User: ")

          # check if user wants to exit the conversation
          if user_message.lower() == "exit":
            break

          # let the agent respond to the user message
          agent_response = agent.continue_conversation(user_message)

          # print the agent's response
          print("Agent: ", agent_response)

# %% [markdown]
# ## Build your own Agent
# Now, go on to use it

# %%
NAME = "james"
PERSONALITY = """
Sarcastic and permanently bothered
"""
MODEL_PROVIDER = PROVIDER
CONTEXT = """
You don't know anything, but you act like if you know everything and always mock the user
"""
GOAL = """
Creating a fun conversation with permanent sarcasm and condescendence
"""

# %%
agent = AIAgent(NAME, PERSONALITY, MODEL_PROVIDER, CONTEXT, GOAL)

# %% [markdown]
# ## And have a little warmup conversation
#
# If you are using this notebook in colab, each answer will take its time, due to gpu constraints. To end the conversation, stop the cell.

# %%
agent.create_conversation()

# %% [markdown]
# # Ok, now it's our AudioIntegration turn
#
# As we progress, remember that an "integration" represents the way an AI agent interfaces with users. In this case, our AudioIntegration enables voice interaction, expanding the environments where our agents can operate and enhancing the interaction experience. Let's gear up!

# %% [markdown]
# ## Install Whisper and Speech T5 requirements

# %%
# install openai's whisper
# !pip install -U openai-whisper

# update the packages
# !sudo apt update && sudo apt install ffmpeg

# %%
# !pip install datasets sentencepiece transformers

# %% [markdown]
# **RESTART THE ENVIRONMENT AND EXECUTE THE LLM SETUP CELLS IN THE ADDENDA**

# %% [markdown]
# ## Speech T5 Setup

# %%
from transformers import SpeechT5Processor, SpeechT5ForTextToSpeech, SpeechT5HifiGan
from datasets import load_dataset
import torch
import soundfile as sf

# Load the processor, model, and vocoder
PROCESSOR = SpeechT5Processor.from_pretrained("microsoft/speecht5_tts")
TTS_MODEL = SpeechT5ForTextToSpeech.from_pretrained("microsoft/speecht5_tts")
vocoder = SpeechT5HifiGan.from_pretrained("microsoft/speecht5_hifigan")

# Load xvector containing speaker's voice characteristics from a dataset
embeddings_dataset = load_dataset("Matthijs/cmu-arctic-xvectors", split="validation")
speaker_embeddings = torch.tensor(embeddings_dataset[7306]["xvector"]).unsqueeze(0)

# %% [markdown]
# ## Audio management setup
#
# Use javascript to record audio.
# Declare `record()` and `play(audio)` functions

# %%
# all imports
from io import BytesIO
from base64 import b64decode
from google.colab import output
from IPython.display import Javascript
import IPython.display as ipd

RECORD = """
const sleep  = time => new Promise(resolve => setTimeout(resolve, time))
const b2text = blob => new Promise(resolve => {
  const reader = new FileReader()
  reader.onloadend = e => resolve(e.srcElement.result)
  reader.readAsDataURL(blob)
})
var record = time => new Promise(async resolve => {
  stream = await navigator.mediaDevices.getUserMedia({ audio: true })
  recorder = new MediaRecorder(stream)
  chunks = []
  recorder.ondataavailable = e => chunks.push(e.data)
  recorder.start()
  await sleep(time)
  recorder.onstop = async ()=>{
    blob = new Blob(chunks)
    text = await b2text(blob)
    resolve(text)
  }
  recorder.stop()
})
"""

def record(sec=3):
    input("Press Enter to start recording...")
    print("Speak Now...")
    display(Javascript(RECORD))
    sec += 1
    s = output.eval_js('record(%d)' % (sec*1000))
    print("Done Recording !")
    b = b64decode(s.split(',')[1].strip())
    return b #byte stream

def play(audio):
  ipd.display(ipd.Audio(audio))

# %% [markdown]
# ## Declare AudioIntegration
#
# The `AudioIntegration` class is a standard integration, showcasing how an agent can operate in different interfaces. Integrations should have functions to receive user inputs and relay agent responses. Here, `get_text` transcribes user speech to text, and `give_response` transforms agent text to speech, enabling voice interaction.

# %%
import IPython.display as ipd
import subprocess
import whisper

USER_TIME_TO_TALK = 5 # This controls how much time to record

class AudioIntegration:

    def get_text(self, sec=USER_TIME_TO_TALK):
        # get user input as audio
        user_audio = record(sec=sec)
        # Save audio to a file
        with open('audio.wav', 'wb') as f:
            f.write(user_audio)
        # transcribe user audio to textimport whisper
        model = whisper.load_model("base")
        result = model.transcribe("audio.wav")
        return result["text"].strip()

    def give_response(self, message):
        # Convert the message to speech
        max_length = 512
        chunks = [message[0:min(len(message), max_length)]]
        chunks.extend([message[i-min(12,len(message)):min(i+max_length,
                                                          len(message))] \
                       for i in range(max_length, len(message), max_length)])
        for chunk in chunks:
          inputs = PROCESSOR(text=chunk, return_tensors="pt")
          speech = TTS_MODEL.generate_speech(inputs["input_ids"],
                                             speaker_embeddings,
                                             vocoder=vocoder)

          # Save the speech to a .wav file
          sf.write("agent_speech.wav", speech.numpy(), samplerate=16000)

          # Display the agent's response
          play('agent_speech.wav')

# %% [markdown]
# ## Test the integration

# %%
integration = AudioIntegration()
integration.get_text()

# %%
integration.give_response("I was walking down the street with two llamas, and one llama say the other llama: `Tu como te llamas?`. Turned out they were spaniards")

# %% [markdown]
# # We will now redefine our AI Agent class
#
# Let's modify the `AIAgent` class to seamlessly accommodate different integrations. By doing so, we'll be able to equip it with the `AudioIntegration` we have built, thereby enriching its interaction capabilities.

# %%
class AIAgent:

    class BasicIntegration:
        # We want to still be able to communicate with our agents the simplest
        # posible way, by default
        def get_text(self):
            return input("User: ")
        def give_response(self, message):
            print("Agent: ", message)

    def __init__(self, name, personality, model_provider, context, goal):
        self.name = name
        self.personality = personality
        self.model_provider = model_provider
        self.context = context
        self.goal = goal
        self.conversation = []

    def _create_conversation(self):
        system_prompt = SYSTEM_PROMPT.format(
            context=self.context,
            personality=self.personality,
            name=self.name,
            goal=self.goal
        )
        conversation_info = {
            "system_prompt": system_prompt,
            "model_provider": self.model_provider,
            "messages": []
        }
        self.conversation=conversation_info

    def continue_conversation(self, message):
        # append user message to the conversation
        self.conversation["messages"].append({
            "role": "user",
            "content": message
        })
        # generate agent response
        agent_response = LLM_SERVING_FN[self.conversation["model_provider"]](
            self.conversation)
        # append agent response to the conversation
        self.conversation["messages"].append({
            "role": "assistant",
            "content": agent_response
        })
        return agent_response

    def create_conversation(self, integration=BasicIntegration()):
        # start a new conversation
        self._create_conversation()

        while True:
          # get user input
          user_message = integration.get_text()
          print("DEBUG:::Received: ", user_message)

          # check if user wants to exit the conversation
          if user_message.lower() in ["exit", "exit."]:
            break

          # let the agent respond to the user message
          agent_response = agent.continue_conversation(user_message)
          print("DEBUG:::Generated: ", agent_response)

          # print the agent's response
          integration.give_response(agent_response)

# %% [markdown]
# ## And let's hear our agent!

# %%
# Rebuild it
agent = AIAgent(NAME, PERSONALITY, MODEL_PROVIDER, CONTEXT, GOAL)

# %%
# Create conversation
agent.create_conversation(integration=AudioIntegration())

# %% [markdown]
# # The last ingredient: Actions
#
# We will build a simple 'multiply' action, usable by our agent, to exemplify our agents' last component.

# %%
class MultiplyAction:

    def get_description(self):
      return "multiply-action", """This actions multiplies two numbers and outputs the result.
      Expected arguments:
      - first: first number
      - second: second number
      Example usage:
      User: What is 6's double?
      Action: {"action": "multiply-action", "args": {"first": 6,"second": 2}}"""

    def activate(self, args):
        return str(args["first"]*args["second"])

# %% [markdown]
# ## Agent redefinition
#
# We empower our agent to make it able to decide if it should use some action

# %%
def extract_json_string(input_string):
    pattern = r'(\{[^{}]*(\{[^{}]*\}[^{}]*)*\})'  # Regular expression pattern
    matches = re.findall(pattern, input_string)

    if matches:
        print(matches)
        my_match = matches[0][0]
        try:
            data = json.loads(my_match)
            return data
        except json.JSONDecodeError:
            return None
    else:
        return None
class AIAgent:
    class BasicIntegration:
        # We want to still be able to communicate with our agents the simplest
        # posible way, by default
        def get_text(self):
            return input("User: ")
        def give_response(self, message):
            print("Agent: ", message)

    class NoneAction:
      def get_description(self):
        return "none-action", """This action should be used when no other action is useful.
        Example usage:
        User: I don't want anything!
        Action: {"action": "none-action", "args": {}}
        User: I want something that you can't do!
        Action: {"action": "none-action", "args": {}}"""

      def activate(self):
        pass

    def __init__(self, name, personality, model_provider, context, goal):
        self.name = name
        self.personality = personality
        self.model_provider = model_provider
        self.context = context
        self.goal = goal
        self.conversation = []

    def _use_actions(self, user_message, actions, counter=0):
        USE_ACTIONS_PROMPT = """You have access to the following actions:
{actions}

        You have to identify what action should be used. Do nothing else.

        User: {user_message}
        Action:"""
        ACTIONS_PROMPT = "\n".join([f"{action_name} : {action_desc}"\
                                    for (action_name, action_desc) in [
                                        action.get_description() for action in actions]])
        prompt = USE_ACTIONS_PROMPT.format(
            context=self.context,
            goal=self.goal,
            actions=ACTIONS_PROMPT,
            user_message=user_message
        )
        print("DEBUG::: Selecting action for ", user_message)
        response = LLM_SERVING_FN["plain"][self.conversation["model_provider"]](prompt)
        print("DEBUG::: Selection result ", response)
        response = response.strip().split('\n')[0].strip()
        resulting_interaction = [{"role": "user", "content": user_message}]
        try:
          parsed_response = extract_json_string(response)
          selected_action = parsed_response["action"]
          if selected_action == "none-action":
              selected_action = "-"
          for action in actions:
              if selected_action == action.get_description()[0]:
                  args = parsed_response["args"]
                  action_response = action.activate(args)
                  resulting_interaction.extend([
                                 {"role": "action", "content": json.dumps(parsed_response)},
                                 {"role": "action", "content": f"Result: {action_response} - This should be explained to the user"}])
                  break
        except Exception as e:
          retry_message = f"""{user_message}
          Action: {response}
          Result: ERROR: {type(e)}->{str(e)}"""
          if counter<3:
            return self._use_actions(retry_message, actions, counter+1)
        return resulting_interaction

    def _create_conversation(self):
        system_prompt = SYSTEM_PROMPT.format(
            context=self.context,
            personality=self.personality,
            name=self.name,
            goal=self.goal
        )
        conversation_info = {
            "system_prompt": system_prompt,
            "model_provider": self.model_provider,
            "messages": []
        }
        self.conversation=conversation_info

    def continue_conversation(self, messages):
        # append user message to the conversation
        self.conversation["messages"].extend(messages)
        # generate agent response
        agent_response = LLM_SERVING_FN[self.conversation["model_provider"]](
            self.conversation)
        # append agent response to the conversation
        self.conversation["messages"].append({
            "role": "assistant",
            "content": agent_response
        })
        return agent_response

    def create_conversation(self, integration=BasicIntegration(), actions=[]):
        actions.append(AIAgent.NoneAction())
        # start a new conversation
        self._create_conversation()

        while True:
          # get user input
          user_message = integration.get_text()
          print("DEBUG:::Received: ", user_message)

          # check if user wants to exit the conversation
          if user_message.lower() in ["exit", "exit."]:
            break

          # let the agent use some action
          user_message_extended = self._use_actions(user_message, actions)
          print("DEBUG:::Actions: ", user_message_extended)

          # let the agent respond to the user message
          agent_response = agent.continue_conversation(user_message_extended)
          print("DEBUG:::Generated: ", agent_response)

          # print the agent's response
          integration.give_response(agent_response)

# %%
# Rebuild it
agent = AIAgent(NAME, PERSONALITY, MODEL_PROVIDER, CONTEXT, GOAL)

# %%
agent.create_conversation(actions=[MultiplyAction()])

# %%
LLM_SERVING_FN

# %% [markdown]
# <img src="https://storage.googleapis.com/yggdrasil-ai-hermod-public/qr-spokes.jpeg" width="100" align="right">
#
# # That's been all! Thank you for your participation!
#
# And, if you want to build your own personalizable agents without any need to think about their inner workings, SpokesAI is there for you!

# %% [markdown]
# # Addendum: What to execute after restarting execution env

# %%
import json
import re

# %% [markdown]
# ## LLM-related variables

# %% [markdown]
# ### OpenAI

# %%
import openai
openai.api_key = "<your-api-key>"

# %%
PROVIDER = "openai"

# %% [markdown]
# ### OpenSource

# %%
from transformers import AutoTokenizer
import torch
import transformers

interesting_models = {
    #"mistral": {
    #    "7B": {
    #        "Instruct": "mistralai/Mistral-7B-Instruct-v0.1",
    #        "Basic": "mistralai/Mistral-7B-v0.1"
    #    }
    #},
    #"llama-2": {
    #    "7B": {
    #        "Chat": "meta-llama/Llama-2-7b-chat-hf",
    #        "Basic": "meta-llama/Llama-2-7b-hf"
    #    },
    #    "13B": {
    #        "Chat": "meta-llama/Llama-2-13b-chat-hf",
    #        "Basic": "meta-llama/Llama-2-13b-hf"
    #    },
    #    "70": {
    #        "Chat": "meta-llama/Llama-2-70b-chat-hf",
    #        "Basic": "meta-llama/Llama-2-70b-hf"
    #    }
    #},
    "falcon": {
        "7B": {
            "Instruct": "tiiuae/falcon-7b-instruct"
        },
        # "180B": {
        #    "Chat": "tiiuae/falcon-180B-chat",
        #    "Basic": "tiiuae/falcon-180B"
        #}
    }
}

PROVIDER = "falcon"
SIZE = "7B"
FINETUNING = "Instruct"

model = interesting_models[PROVIDER][SIZE][FINETUNING]
print(model)

tokenizer = AutoTokenizer.from_pretrained(model)

PIPELINE = transformers.pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    torch_dtype=torch.bfloat16,
    device_map="auto",
    max_length=1000,
    do_sample=True,
    top_k=10,
    num_return_sequences=1,
    eos_token_id=tokenizer.eos_token_id,
    pad_token_id=tokenizer.eos_token_id,
)

# %% [markdown]
# ## LLM-related functions

# %%
LLM_SERVING_FN = {"plain": {}}

# %% [markdown]
# ### OpenAI

# %%
import tiktoken

openai_model = "gpt-3.5-turbo"

def count_tokens(text, model):
    """
    This function counts the number of tokens in a text.
    Parameters:
        text: The text to count the tokens of.
        model: The model to use for tokenization.
    Returns:
        The number of tokens in the text."""
    encoding = tiktoken.encoding_for_model(model)
    return len(encoding.encode(text))

def generate_answer(conversation_info):
    """
    This function will continue the conversation.
    Parameters:
        conversation_info: The information of the conversation
        message: The message to append
    """
    print("Generating answer")
    messages = [{"role": "system", "content": conversation_info["system_prompt"]}]
    for msg in conversation_info["messages"]:
        new_message = {"role": msg["role"] if msg["role"] \
                         in ("user", "assistant", "system") else "function",
                         "content": msg["content"]}
        if new_message["role"] == "function":
          new_message["name"] = "unknown"
        messages.append(new_message)

    # Limit the conversation history to a certain number of tokens
    max_context_length = 3500  # Adjust this value based on your desired context length
    current_context_length = sum([count_tokens(msg["content"], openai_model) for msg in messages])

    while current_context_length > max_context_length:
        removed_message = messages.pop(1)  # Remove the earliest non-system message
        current_context_length -= count_tokens(removed_message["content"], openai_model)

    full_prompt = {
        "model": openai_model,
        "messages": messages
    }
    response = openai.ChatCompletion.create(**full_prompt)
    return response["choices"][0]["message"]["content"]

def simple_prompt(prompt):
    full_prompt = {
        "model": openai_model,
        "messages": [{"role": "user", "content": prompt},]
    }
    response = openai.ChatCompletion.create(**full_prompt)
    return response["choices"][0]["message"]["content"]

LLM_SERVING_FN["plain"]["openai"] = simple_prompt

LLM_SERVING_FN["openai"] = generate_answer

# %% [markdown]
# ### OpenSource

# %%
from langchain import HuggingFacePipeline

llm = HuggingFacePipeline(pipeline=PIPELINE)

def generate_answer(conversation_info):
    """
    This function will continue the conversation.
    Parameters:
        conversation_info: Dict object containing the information of the conversation
        message: The message to append
    """

    # Format messages to be compatible with the model
    prompt = conversation_info["system_prompt"] + "\n"
    for msg in conversation_info["messages"]:
        prompt += msg["role"].capitalize() + ": " + msg["content"] + "\n"

    # Generate response
    response = llm(prompt + "Assistant:")
    return response.split("User")[0]

LLM_SERVING_FN[PROVIDER] = generate_answer
LLM_SERVING_FN["plain"][PROVIDER] = llm

# %% [markdown]
# ## Whisper & Speech T5 setup

# %%
from transformers import SpeechT5Processor, SpeechT5ForTextToSpeech, SpeechT5HifiGan
from datasets import load_dataset
import torch
import soundfile as sf
from io import BytesIO
from base64 import b64decode
from google.colab import output
from IPython.display import Javascript
import IPython.display as ipd

# Load the processor, model, and vocoder
PROCESSOR = SpeechT5Processor.from_pretrained("microsoft/speecht5_tts")
TTS_MODEL = SpeechT5ForTextToSpeech.from_pretrained("microsoft/speecht5_tts")
vocoder = SpeechT5HifiGan.from_pretrained("microsoft/speecht5_hifigan")

# Load xvector containing speaker's voice characteristics from a dataset
embeddings_dataset = load_dataset("Matthijs/cmu-arctic-xvectors", split="validation")
speaker_embeddings = torch.tensor(embeddings_dataset[7306]["xvector"]).unsqueeze(0)

RECORD = """
const sleep  = time => new Promise(resolve => setTimeout(resolve, time))
const b2text = blob => new Promise(resolve => {
  const reader = new FileReader()
  reader.onloadend = e => resolve(e.srcElement.result)
  reader.readAsDataURL(blob)
})
var record = time => new Promise(async resolve => {
  stream = await navigator.mediaDevices.getUserMedia({ audio: true })
  recorder = new MediaRecorder(stream)
  chunks = []
  recorder.ondataavailable = e => chunks.push(e.data)
  recorder.start()
  await sleep(time)
  recorder.onstop = async ()=>{
    blob = new Blob(chunks)
    text = await b2text(blob)
    resolve(text)
  }
  recorder.stop()
})
"""

def record(sec=3):
    input("Press Enter to start recording...")
    print("Speak Now...")
    display(Javascript(RECORD))
    sec += 1
    s = output.eval_js('record(%d)' % (sec*1000))
    print("Done Recording !")
    b = b64decode(s.split(',')[1].strip())
    return b #byte stream

def play(audio):
  ipd.display(ipd.Audio(audio))
# Out:
# Downloading (…)rocessor_config.json:   0%|          | 0.00/433 [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/232 [00:00<?, ?B/s]
# Downloading spm_char.model:   0%|          | 0.00/238k [00:00<?, ?B/s]
# Downloading (…)in/added_tokens.json:   0%|          | 0.00/40.0 [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/234 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/2.06k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/585M [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/636 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/50.7M [00:00<?, ?B/s]
# Downloading builder script:   0%|          | 0.00/1.36k [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/1.01k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/17.9M [00:00<?, ?B/s]
# Generating validation split: 0 examples [00:00, ? examples/s]

# %% [markdown]
# ## AudioIntegration

# %%
import IPython.display as ipd
import subprocess
import whisper

USER_TIME_TO_TALK = 5 # This controls how much time to record

class AudioIntegration:

    def get_text(self, sec=USER_TIME_TO_TALK):
        # get user input as audio
        user_audio = record(sec=sec)
        # Save audio to a file
        with open('audio.wav', 'wb') as f:
            f.write(user_audio)
        # transcribe user audio to textimport whisper
        model = whisper.load_model("base")
        result = model.transcribe("audio.wav")
        return result["text"].strip()

    def give_response(self, message):
        # Convert the message to speech
        max_length = 512
        chunks = [message[0:min(len(message), max_length)]]
        chunks.extend([message[i-min(12,len(message)):min(i+max_length,
                                                          len(message))] \
                       for i in range(max_length, len(message), max_length)])
        for chunk in chunks:
          inputs = PROCESSOR(text=chunk, return_tensors="pt")
          speech = TTS_MODEL.generate_speech(inputs["input_ids"],
                                             speaker_embeddings,
                                             vocoder=vocoder)

          # Save the speech to a .wav file
          sf.write("agent_speech.wav", speech.numpy(), samplerate=16000)

          # Display the agent's response
          play('agent_speech.wav')

# %% [markdown]
# ## MultiplyAction

# %%
class MultiplyAction:

    def get_description(self):
      return "multiply-action", """This actions multiplies two numbers and outputs the result.
      Expected arguments:
      - first: first number
      - second: second number
      Example usage:
      Action: {"action": "multiply-action", "args": {"first": 6, "second": 2}}"""

    def activate(self, args):
        return str(args["first"]*args["second"])

# %% [markdown]
# ## Agents

# %%
SYSTEM_PROMPT = """You're an AI assistant called {name}.
This is your personality:
{personality}.

You are aware of the following context:
{context}.
When you don't know something, you say it. Your knowledge is focused in your context.

Your goal in this conversation is:
{goal}.
You must focus in your goal, if user tries to change conversation topic, you should dismiss it. You never write on behalf of user. You only write Assistant Messages. You only write one message at a time.
"""

NAME = "james"
PERSONALITY = """
Sarcastic and permanently bothered
"""
MODEL_PROVIDER = PROVIDER
CONTEXT = """
You don't know anything, but you act like if you know everything and always mock the user
"""
GOAL = """
Creating a fun conversation with permanent sarcasm and condescendence
"""

# %% [markdown]
# ### Basic

# %%
class AIAgent:

    def __init__(self, name, personality, model_provider, context, goal):
        self.name = name
        self.personality = personality
        self.model_provider = model_provider
        self.context = context
        self.goal = goal
        self.conversation = []

    def _create_conversation(self):
        system_prompt = SYSTEM_PROMPT.format(
            context=self.context,
            personality=self.personality,
            name=self.name,
            goal=self.goal
        )
        conversation_info = {
            "system_prompt": system_prompt,
            "model_provider": self.model_provider,
            "messages": []
        }
        self.conversation=conversation_info

    def continue_conversation(self, message):
        # append user message to the conversation
        self.conversation["messages"].append({
            "role": "user",
            "content": message
        })
        # generate agent response
        agent_response = LLM_SERVING_FN[self.conversation["model_provider"]](
            self.conversation)
        # append agent response to the conversation
        self.conversation["messages"].append({
            "role": "assistant",
            "content": agent_response
        })
        return agent_response

    def create_conversation(self):
        # start a new conversation
        self._create_conversation()

        while True:
          # get user input
          user_message = input("User: ")

          # check if user wants to exit the conversation
          if user_message.lower() == "exit":
            break

          # let the agent respond to the user message
          agent_response = agent.continue_conversation(user_message)

          # print the agent's response
          print("Agent: ", agent_response)

# %% [markdown]
# ### With Integrations

# %%
class AIAgent:

    class BasicIntegration:
        # We want to still be able to communicate with our agents the simplest
        # posible way, by default
        def get_text(self):
            return input("User: ")
        def give_response(self, message):
            print("Agent: ", message)

    def __init__(self, name, personality, model_provider, context, goal):
        self.name = name
        self.personality = personality
        self.model_provider = model_provider
        self.context = context
        self.goal = goal
        self.conversation = []

    def _create_conversation(self):
        system_prompt = SYSTEM_PROMPT.format(
            context=self.context,
            personality=self.personality,
            name=self.name,
            goal=self.goal
        )
        conversation_info = {
            "system_prompt": system_prompt,
            "model_provider": self.model_provider,
            "messages": []
        }
        self.conversation=conversation_info

    def continue_conversation(self, message):
        # append user message to the conversation
        self.conversation["messages"].append({
            "role": "user",
            "content": message
        })
        # generate agent response
        agent_response = LLM_SERVING_FN[self.conversation["model_provider"]](
            self.conversation)
        # append agent response to the conversation
        self.conversation["messages"].append({
            "role": "assistant",
            "content": agent_response
        })
        return agent_response

    def create_conversation(self, integration=BasicIntegration()):
        # start a new conversation
        self._create_conversation()

        while True:
          # get user input
          user_message = integration.get_text()
          print("DEBUG:::Received: ", user_message)

          # check if user wants to exit the conversation
          if user_message.lower() in ["exit", "exit."]:
            break

          # let the agent respond to the user message
          agent_response = agent.continue_conversation(user_message)
          print("DEBUG:::Generated: ", agent_response)

          # print the agent's response
          integration.give_response(agent_response)

# %% [markdown]
# ### With Actions

# %%
def extract_json_string(input_string):
    pattern = r'(\{[^{}]*(\{[^{}]*\}[^{}]*)*\})'  # Regular expression pattern
    matches = re.findall(pattern, input_string)

    if matches:
        print(matches)
        my_match = matches[0][0]
        try:
            data = json.loads(my_match)
            return data
        except json.JSONDecodeError:
            return None
    else:
        return None
class AIAgent:
    class BasicIntegration:
        # We want to still be able to communicate with our agents the simplest
        # posible way, by default
        def get_text(self):
            return input("User: ")
        def give_response(self, message):
            print("Agent: ", message)

    class NoneAction:
      def get_description(self):
        return "none-action", """This action should be used when no other action is useful.
        Example usage:
        User: I don't want anything!
        Action: {"action": "none-action", "args": {}}
        User: I want something that you can't do!
        Action: {"action": "none-action", "args": {}}"""

      def activate(self):
        pass

    def __init__(self, name, personality, model_provider, context, goal):
        self.name = name
        self.personality = personality
        self.model_provider = model_provider
        self.context = context
        self.goal = goal
        self.conversation = []

    def _use_actions(self, user_message, actions, counter=0):
        USE_ACTIONS_PROMPT = """You have access to the following actions:
{actions}

        You have to identify what action should be used. Do nothing else.

        User: {user_message}
        Action:"""
        ACTIONS_PROMPT = "\n".join([f"{action_name} : {action_desc}"\
                                    for (action_name, action_desc) in [
                                        action.get_description() for action in actions]])
        prompt = USE_ACTIONS_PROMPT.format(
            context=self.context,
            goal=self.goal,
            actions=ACTIONS_PROMPT,
            user_message=user_message
        )
        print("DEBUG::: Selecting action for ", user_message)
        response = LLM_SERVING_FN["plain"][self.conversation["model_provider"]](prompt)
        print("DEBUG::: Selection result ", response)
        response = response.strip().split('\n')[0].strip()
        resulting_interaction = [{"role": "user", "content": user_message}]
        try:
          parsed_response = extract_json_string(response)
          selected_action = parsed_response["action"]
          if selected_action == "none-action":
              selected_action = "-"
          for action in actions:
              if selected_action == action.get_description()[0]:
                  args = parsed_response["args"]
                  action_response = action.activate(args)
                  resulting_interaction.extend([
                                 {"role": "action", "content": json.dumps(parsed_response)},
                                 {"role": "action", "content": f"Result: {action_response} - This should be explained to the user"}])
                  break
        except Exception as e:
          retry_message = f"""{user_message}
          Action: {response}
          Result: ERROR: {type(e)}->{str(e)}"""
          if counter<3:
            return self._use_actions(retry_message, actions, counter+1)
        return resulting_interaction

    def _create_conversation(self):
        system_prompt = SYSTEM_PROMPT.format(
            context=self.context,
            personality=self.personality,
            name=self.name,
            goal=self.goal
        )
        conversation_info = {
            "system_prompt": system_prompt,
            "model_provider": self.model_provider,
            "messages": []
        }
        self.conversation=conversation_info

    def continue_conversation(self, messages):
        # append user message to the conversation
        self.conversation["messages"].extend(messages)
        # generate agent response
        agent_response = LLM_SERVING_FN[self.conversation["model_provider"]](
            self.conversation)
        # append agent response to the conversation
        self.conversation["messages"].append({
            "role": "assistant",
            "content": agent_response
        })
        return agent_response

    def create_conversation(self, integration=BasicIntegration(), actions=[]):
        actions.append(AIAgent.NoneAction())
        # start a new conversation
        self._create_conversation()

        while True:
          # get user input
          user_message = integration.get_text()
          print("DEBUG:::Received: ", user_message)

          # check if user wants to exit the conversation
          if user_message.lower() in ["exit", "exit."]:
            break

          # let the agent use some action
          user_message_extended = self._use_actions(user_message, actions)
          print("DEBUG:::Actions: ", user_message_extended)

          # let the agent respond to the user message
          agent_response = agent.continue_conversation(user_message_extended)
          print("DEBUG:::Generated: ", agent_response)

          # print the agent's response
          integration.give_response(agent_response)
